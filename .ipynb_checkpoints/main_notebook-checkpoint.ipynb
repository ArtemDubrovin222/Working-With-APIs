# %% [markdown]
# # Use this notebook for your 3 choices of APIs

# %%
import pandas as pd
import requests
import json
from pandas import json_normalize

# %%
import requests

def get_http_cat(status_code):
    url = f"https://http.cat/{status_code}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.content
    else:
        return None

status_code = 404
cat_image = get_http_cat(status_code)
if cat_image:
    with open(f"{status_code}.jpg", "wb") as f:
        f.write(cat_image)
    print(f"Cat image for status code {status_code} saved successfully.")
else:
    print(f"Failed to retrieve cat image for status code {status_code}.")
# Out:
# Cat image for status code 404 saved successfully.

# %%
#2
url2 = "https://www.cbr.ru/scripts/XML_daily.asp?date_req=02/03/2022"
response2 = requests.get(url2)
print(response2.content)
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><ValCurs Date="02.03.2022" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>66,7817</Value><VunitRate>66,7817</VunitRate></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><Value>53,9998</Value><VunitRate>53,9998</VunitRate></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><Value>123,1411</Value><VunitRate>123,1411</VunitRate></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xf5 \xe4\xf0\xe0\xec\xee\xe2</Name><Value>18,8196</Value><VunitRate>0,188196</VunitRate></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><Value>29,4765</Value><VunitRate>29,4765</VunitRate></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><Value>52,5944</Value><VunitRate>52,5944</VunitRate></Valute><Valute ID="R01115"><NumCode>986</
# %%
import xml.etree.ElementTree as ET
data_all = response2.text
#print(type(data_all))

# %%
root = ET.fromstring(data_all)
# Create an empty list to store dictionaries
data = []
# Iterate through Valute elements and extract values
for entry in root.findall('Valute'):
    id = entry.attrib['ID']
    numCode = entry.find('NumCode').text
    charcode = entry.find('CharCode').text
    nominal = entry.find('Nominal').text
    name = entry.find('Name').text
    value = entry.find('Value').text
    vunitRate = entry.find('VunitRate').text
    
    # Append extracted data to list of dictionaries
    data.append({"ID": id, "NumCode": numCode, "CharCode": charcode, 
                 "Nominal": nominal, "Name": name, "Value": value, 
                 "VunitRate": vunitRate})
# Convert list of dictionaries to DataFrame
df = pd.DataFrame(data)
df
# Out:
#          ID NumCode CharCode Nominal  \
# 0    R01010     036      AUD       1
# 1   R01020A     944      AZN       1
# 2    R01035     826      GBP       1
# 3    R01060     051      AMD     100
# 4   R01090B     933      BYN       1
# 5    R01100     975      BGN       1
# 6    R01115     986      BRL       1
# 7    R01135     348      HUF     100
# 8    R01200     344      HKD       1
# 9    R01215     208      DKK       1
# 10   R01235     840      USD       1
# 11   R01239     978      EUR       1
# 12   R01270     356      INR      10
# 13   R01335     398      KZT     100
# 14   R01350     124      CAD       1
# 15   R01370     417      KGS      10
# 16   R01375     156      CNY       1
# 17   R01500     498      MDL      10
# 18   R01535     578      NOK       1
# 19   R01565     985      PLN       1
# 20  R01585F     946      RON       1
# 21   R01589     960      XDR       1
# 22   R01625     702      SGD       1
# 23   R01670     972      TJS      10
# 24  R01700J     949      TRY      10
# 25  R01710A     934      TMT       1
# 26   R01717     860      UZS   10000
# 27   R01720     980      UAH      10
# 28   R01760     203      CZK      10
# 29   R01770     752      SEK      10
# 30   R01775     756      CHF       1
# 31   R01810     710      ZAR      10
# 32   R01815     410      KRW    1000
# 33   R01820     392      JPY     100
#
#                                         Name     Value  VunitRate
# 0                       Австралийский доллар   66,7817    66,7817
# 1                      Азербайджанский манат   53,9998    53,9998
# 2   Фунт стерлингов Соединенного королевства  123,1411   123,1411
# 3                           Армянских драмов   18,8196   0,188196
# 4                          Белорусский рубль   29,4765    29,4765
# 5                             Болгарский лев   52,5944    52,5944
# 6                           Бразильский реал   17,7795    17,7795
# 7                        Венгерских форинтов   27,7437   0,277437
# 8                         Гонконгский доллар   11,7413    11,7413
# 9                              Датская крона   13,8309    13,8309
# 10                                Доллар США   91,7457    91,7457
# 11                                      Евро  102,9112   102,9112
# 12                           Индийских рупий   12,1817    1,21817
# 13                       Казахстанских тенге   18,6621   0,186621
# 14                          Канадский доллар   72,4346    72,4346
# 15                          Киргизских сомов   10,7936    1,07936
# 16                            Китайский юань   14,5340     14,534
# 17                           Молдавских леев   49,8618    4,98618
# 18                          Норвежская крона   10,4292    10,4292
# 19                           Польский злотый   21,9288    21,9288
# 20                             Румынский лей   20,7899    20,7899
# 21     СДР (специальные права заимствования)  127,9724   127,9724
# 22                       Сингапурский доллар   67,7640     67,764
# 23                         Таджикских сомони   81,2988    8,12988
# 24                              Турецких лир   66,1464    6,61464
# 25                   Новый туркменский манат   26,2506    26,2506
# 26                           Узбекских сумов   84,3840  0,0084384
# 27                         Украинских гривен   30,4044    3,04044
# 28                              Чешских крон   41,0266    4,10266
# 29                             Шведских крон   96,7925    9,67925
# 30                         Швейцарский франк  100,2028   100,2028
# 31                    Южноафриканских рэндов   59,9571    5,99571
# 32                      Вон Республики Корея   76,5619  0,0765619
# 33                              Японских иен   79,7962   0,797962

# %%
#3
url='https://api.coinlore.net/api/ticker/?id=90,80'

# %%
response = requests.get(url)
response
results = response.json()
results
# Out:
# [{'id': '90',
#   'symbol': 'BTC',
#   'name': 'Bitcoin',
#   'nameid': 'bitcoin',
#   'rank': 1,
#   'price_usd': '64087.73',
#   'percent_change_24h': '-0.27',
#   'percent_change_1h': '-0.10',
#   'percent_change_7d': '0.13',
#   'price_btc': '1.00',
#   'market_cap_usd': '1261891204653.30',
#   'volume24': 29337101691.62626,
#   'volume24a': 23282627646.39313,
#   'csupply': '19690059.00',
#   'tsupply': '19690059',
#   'msupply': '21000000'},
#  {'id': '80',
#   'symbol': 'ETH',
#   'name': 'Ethereum',
#   'nameid': 'ethereum',
#   'rank': 2,
#   'price_usd': '3099.54',
#   'percent_change_24h': '-1.84',
#   'percent_change_1h': '-0.39',
#   'percent_change_7d': '-3.83',
#   'price_btc': '0.048367',
#   'market_cap_usd': '379307470660.91',
#   'volume24': 11770827217.12367,
#   'volume24a': 8779244846.957388,
#   'csupply': '122375302.00',
#   'tsupply': '122375302',
#   'msupply': ''}]

# %%
json_normalize(results).T.reset_index()
# Out:
#                  index                   0                   1
# 0                   id                  90                  80
# 1               symbol                 BTC                 ETH
# 2                 name             Bitcoin            Ethereum
# 3               nameid             bitcoin            ethereum
# 4                 rank                   1                   2
# 5            price_usd            64087.73             3099.54
# 6   percent_change_24h               -0.27               -1.84
# 7    percent_change_1h               -0.10               -0.39
# 8    percent_change_7d                0.13               -3.83
# 9            price_btc                1.00            0.048367
# 10      market_cap_usd    1261891204653.30     379307470660.91
# 11            volume24  29337101691.626259  11770827217.123671
# 12           volume24a  23282627646.393131   8779244846.957388
# 13             csupply         19690059.00        122375302.00
# 14             tsupply            19690059           122375302
# 15             msupply            21000000

# %%
data= json_normalize(results).T.reset_index()

# %%
data.to_csv("cripto.csv", index=False)
